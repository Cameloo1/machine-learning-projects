# %% [markdown]
# # Exploratory Data Analysis & Feature Inspection
#
# This notebook is intended for exploratory data analysis and feature inspection for the SPY intraday dataset.
#
# All core feature engineering logic lives in `rl_trading/features.py`.
#
# ## Contents
#
# 1. Load and inspect raw SPY intraday data
# 2. Visualize OHLCV distributions
# 3. Apply feature engineering pipeline
# 4. Inspect computed features
# 5. Verify train/val/test splits
#
# ---
#
# **Note:** Place your SPY intraday CSV file at `data/spy_30m_2019_2025.csv` before running this notebook.

# %%
# Example usage (uncomment when data is available)
# import sys
# sys.path.insert(0, '..')
#
# from rl_trading.config import get_default_configs
# from rl_trading.data_loader import SPYDataLoader
# from rl_trading.features import add_basic_features, get_feature_columns, FeatureScaler
#
# data_cfg, feat_cfg, train_cfg = get_default_configs()
# loader = SPYDataLoader(data_cfg)
# train_df, val_df, test_df = loader.get_splits()
