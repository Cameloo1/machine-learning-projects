# %% [markdown]
# # 02 – Modeling & Explainability
#
# Quick interactive hooks to experiment with the training, evaluation, and SHAP explanation workflow defined in `src/`.

# %%
import joblib
import pandas as pd

from src import config
from src.evaluate import main as evaluate_models
from src.explain import main as shap_main
from src.train import main as train_models

config.ensure_directories()

# %%
# Trigger training inside the notebook (optional; long-running)
train_models()

# %%
evaluate_models()

# %%
shap_main(sample_count=200)

# %%
pd.read_csv(config.EXPLANATIONS_PATH).head()
